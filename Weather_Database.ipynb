# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        for i in city_weather['weather']:
            city_description=i["description"]
              
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),"Country": city_country,"Lat": city_lat,"Lng": city_lng,"Max Temp": city_max_temp,"Humidity": city_humidity,"Cloudiness": city_clouds,"Wind Speed": city_wind,"Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | normal
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | haines junction
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | australind
# Processing Record 6 of Set 1 | fortuna
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | xuanhua
# Processing Record 12 of Set 1 | alice springs
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | khandagayty
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | broken hill
# Processing Record 22 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 1 | tarland
# City not found. Skipping...
# Processing Record 24 of Set 1 | port-gentil
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | rottingdean
# Processing Record 27 of Set 1 | balykshi
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | arlit
# Processing Record 30 of Set 1 | hervey bay
# Processing Record 31 of Set 1 | senneterre
# Processing Record 32 of Set 1 | blackwater
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | burns lake
# Processing Record 35 of Set 1 | poronaysk
# Processing Record 36 of Set 1 | ilulissat
# Processing Record 37 of Set 1 | carberry
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | ryotsu
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | mandurah
# Processing Record 42 of Set 1 | fukue
# Processing Record 43 of Set 1 | agva
# City not found. Skipping...
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | emerald
# Processing Record 46 of Set 1 | itarema
# Processing Record 47 of Set 1 | cayenne
# Processing Record 48 of Set 1 | okandja
# City not found. Skipping...
# Processing Record 49 of Set 1 | jalapa
# Processing Record 50 of Set 1 | lewisville
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | victoria point
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | namibe
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | yar-sale
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | lazaro cardenas
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | kut chap
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | miramar
# Processing Record 15 of Set 2 | alekseyevsk
# Processing Record 16 of Set 2 | alvorada
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | novospasskoye
# Processing Record 19 of Set 2 | comodoro rivadavia
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | barcelos
# Processing Record 22 of Set 2 | seymour
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | ponta do sol
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | rawson
# Processing Record 27 of Set 2 | talnakh
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | geneva
# Processing Record 32 of Set 2 | ransang
# Processing Record 33 of Set 2 | lodja
# Processing Record 34 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | tocopilla
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | jiuquan
# Processing Record 39 of Set 2 | okhotsk
# Processing Record 40 of Set 2 | toyooka
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 2 | clyde river
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 2 | lumby
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | lompoc
# Processing Record 1 of Set 3 | vila franca do campo
# Processing Record 2 of Set 3 | dongsheng
# Processing Record 3 of Set 3 | arbagar
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | mildura
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | zalantun
# Processing Record 9 of Set 3 | vila velha
# Processing Record 10 of Set 3 | madera
# Processing Record 11 of Set 3 | tanete
# Processing Record 12 of Set 3 | yerofey pavlovich
# Processing Record 13 of Set 3 | hamilton
# Processing Record 14 of Set 3 | yinchuan
# Processing Record 15 of Set 3 | itacare
# Processing Record 16 of Set 3 | kars
# Processing Record 17 of Set 3 | puerto palomas
# Processing Record 18 of Set 3 | punta arenas
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | san quintin
# Processing Record 21 of Set 3 | kavieng
# Processing Record 22 of Set 3 | dicabisagan
# Processing Record 23 of Set 3 | whitehorse
# Processing Record 24 of Set 3 | celestun
# Processing Record 25 of Set 3 | vanderhoof
# Processing Record 26 of Set 3 | nanortalik
# Processing Record 27 of Set 3 | ambunti
# Processing Record 28 of Set 3 | bathsheba
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | atlantic beach
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | alto araguaia
# Processing Record 34 of Set 3 | zhanakorgan
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | camacha
# Processing Record 37 of Set 3 | srandakan
# Processing Record 38 of Set 3 | praia
# Processing Record 39 of Set 3 | anadyr
# Processing Record 40 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 3 | de-kastri
# Processing Record 42 of Set 3 | willowmore
# Processing Record 43 of Set 3 | tonantins
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | saint george
# Processing Record 46 of Set 3 | grindavik
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | riviere-au-renard
# Processing Record 49 of Set 3 | adeje
# Processing Record 50 of Set 3 | waipawa
# Processing Record 1 of Set 4 | ambon
# Processing Record 2 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | kyzyl-mazhalyk
# Processing Record 5 of Set 4 | burnie
# Processing Record 6 of Set 4 | olavarria
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | mayo
# Processing Record 9 of Set 4 | tura
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | bilma
# Processing Record 12 of Set 4 | aswan
# Processing Record 13 of Set 4 | plettenberg bay
# Processing Record 14 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 4 | tomatlan
# Processing Record 16 of Set 4 | broome
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | bluff
# Processing Record 19 of Set 4 | sept-iles
# Processing Record 20 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 21 of Set 4 | mehamn
# Processing Record 22 of Set 4 | matara
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | biograd na moru
# Processing Record 25 of Set 4 | kahului
# Processing Record 26 of Set 4 | konya
# Processing Record 27 of Set 4 | muros
# Processing Record 28 of Set 4 | puerto del rosario
# Processing Record 29 of Set 4 | tralee
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | duki
# Processing Record 32 of Set 4 | guiglo
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | ancud
# Processing Record 35 of Set 4 | nizwa
# Processing Record 36 of Set 4 | zhigansk
# Processing Record 37 of Set 4 | sembe
# Processing Record 38 of Set 4 | seoul
# Processing Record 39 of Set 4 | yanam
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 4 | caravelas
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | hobyo
# Processing Record 45 of Set 4 | benguela
# Processing Record 46 of Set 4 | kamalpur
# Processing Record 47 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 48 of Set 4 | murgab
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 50 of Set 4 | ribeira grande
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | xingyi
# Processing Record 3 of Set 5 | saint-georges
# Processing Record 4 of Set 5 | olenino
# Processing Record 5 of Set 5 | touho
# Processing Record 6 of Set 5 | boyolangu
# Processing Record 7 of Set 5 | quatre cocos
# Processing Record 8 of Set 5 | barrow
# Processing Record 9 of Set 5 | zeya
# Processing Record 10 of Set 5 | rastolita
# Processing Record 11 of Set 5 | college
# Processing Record 12 of Set 5 | arraial do cabo
# Processing Record 13 of Set 5 | nikolskoye
# Processing Record 14 of Set 5 | dalvik
# Processing Record 15 of Set 5 | sinnamary
# Processing Record 16 of Set 5 | gizo
# Processing Record 17 of Set 5 | port hardy
# Processing Record 18 of Set 5 | krasnoselkup
# Processing Record 19 of Set 5 | limaong
# Processing Record 20 of Set 5 | nome
# Processing Record 21 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | taldan
# Processing Record 24 of Set 5 | baturaja
# Processing Record 25 of Set 5 | oistins
# Processing Record 26 of Set 5 | masterton
# Processing Record 27 of Set 5 | zabid
# Processing Record 28 of Set 5 | xai-xai
# Processing Record 29 of Set 5 | arman
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | kholm
# Processing Record 33 of Set 5 | beringovskiy
# Processing Record 34 of Set 5 | saskylakh
# Processing Record 35 of Set 5 | norman wells
# Processing Record 36 of Set 5 | adrar
# Processing Record 37 of Set 5 | bredasdorp
# Processing Record 38 of Set 5 | ngunguru
# Processing Record 39 of Set 5 | muli
# Processing Record 40 of Set 5 | bubaque
# Processing Record 41 of Set 5 | new albany
# Processing Record 42 of Set 5 | henties bay
# Processing Record 43 of Set 5 | makakilo city
# Processing Record 44 of Set 5 | khoy
# Processing Record 45 of Set 5 | zhanaozen
# Processing Record 46 of Set 5 | faya
# Processing Record 47 of Set 5 | olafsvik
# Processing Record 48 of Set 5 | huiloapan
# Processing Record 49 of Set 5 | new norfolk
# Processing Record 50 of Set 5 | kuusamo
# Processing Record 1 of Set 6 | husavik
# Processing Record 2 of Set 6 | pontianak
# Processing Record 3 of Set 6 | baghmara
# Processing Record 4 of Set 6 | pacifica
# Processing Record 5 of Set 6 | naze
# Processing Record 6 of Set 6 | aripuana
# Processing Record 7 of Set 6 | kurchum
# Processing Record 8 of Set 6 | puerto ayora
# Processing Record 9 of Set 6 | magnolia
# Processing Record 10 of Set 6 | dalianwan
# Processing Record 11 of Set 6 | chokurdakh
# Processing Record 12 of Set 6 | russell
# Processing Record 13 of Set 6 | port hedland
# Processing Record 14 of Set 6 | kaeo
# Processing Record 15 of Set 6 | patrasaer
# Processing Record 16 of Set 6 | evanston
# Processing Record 17 of Set 6 | myitkyina
# Processing Record 18 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 6 | berlevag
# Processing Record 20 of Set 6 | honningsvag
# Processing Record 21 of Set 6 | bagotville
# Processing Record 22 of Set 6 | kruisfontein
# Processing Record 23 of Set 6 | yulara
# Processing Record 24 of Set 6 | realeza
# Processing Record 25 of Set 6 | hasaki
# Processing Record 26 of Set 6 | fereydun kenar
# Processing Record 27 of Set 6 | adre
# Processing Record 28 of Set 6 | diffa
# Processing Record 29 of Set 6 | kichera
# Processing Record 30 of Set 6 | honiara
# Processing Record 31 of Set 6 | taiyuan
# Processing Record 32 of Set 6 | borba
# Processing Record 33 of Set 6 | yingzhong
# City not found. Skipping...
# Processing Record 34 of Set 6 | airai
# Processing Record 35 of Set 6 | sibolga
# Processing Record 36 of Set 6 | san pedro
# Processing Record 37 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 6 | skibbereen
# Processing Record 39 of Set 6 | pochutla
# Processing Record 40 of Set 6 | novyy urengoy
# Processing Record 41 of Set 6 | dhidhdhoo
# Processing Record 42 of Set 6 | pacific grove
# Processing Record 43 of Set 6 | kasamwa
# Processing Record 44 of Set 6 | maxixe
# Processing Record 45 of Set 6 | si bun ruang
# Processing Record 46 of Set 6 | katherine
# Processing Record 47 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 6 | soyo
# Processing Record 49 of Set 6 | oneonta
# Processing Record 50 of Set 6 | quang ngai
# Processing Record 1 of Set 7 | eureka
# Processing Record 2 of Set 7 | ust-tsilma
# Processing Record 3 of Set 7 | padang
# Processing Record 4 of Set 7 | narsaq
# Processing Record 5 of Set 7 | harper
# Processing Record 6 of Set 7 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 7 of Set 7 | mitzic
# Processing Record 8 of Set 7 | staunton
# Processing Record 9 of Set 7 | okha
# Processing Record 10 of Set 7 | faanui
# Processing Record 11 of Set 7 | villa vazquez
# City not found. Skipping...
# Processing Record 12 of Set 7 | kununurra
# Processing Record 13 of Set 7 | mackay
# Processing Record 14 of Set 7 | vicksburg
# Processing Record 15 of Set 7 | geilo
# Processing Record 16 of Set 7 | nowa sol
# Processing Record 17 of Set 7 | dunedin
# Processing Record 18 of Set 7 | moyo
# Processing Record 19 of Set 7 | batagay-alyta
# Processing Record 20 of Set 7 | eregli
# Processing Record 21 of Set 7 | ayagoz
# Processing Record 22 of Set 7 | chanika
# Processing Record 23 of Set 7 | port lincoln
# Processing Record 24 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 7 | carutapera
# Processing Record 26 of Set 7 | chuy
# Processing Record 27 of Set 7 | tromso
# Processing Record 28 of Set 7 | kiruna
# Processing Record 29 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 7 | zavetnoye
# Processing Record 31 of Set 7 | aguimes
# Processing Record 32 of Set 7 | prince rupert
# Processing Record 33 of Set 7 | asau
# Processing Record 34 of Set 7 | pemangkat
# Processing Record 35 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 7 | selma
# Processing Record 37 of Set 7 | bria
# Processing Record 38 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 7 | boa vista
# Processing Record 40 of Set 7 | lasa
# Processing Record 41 of Set 7 | semirom
# Processing Record 42 of Set 7 | praia da vitoria
# Processing Record 43 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 7 | ahipara
# Processing Record 45 of Set 7 | surab
# Processing Record 46 of Set 7 | half moon bay
# Processing Record 47 of Set 7 | shimoda
# Processing Record 48 of Set 7 | ramsar
# Processing Record 49 of Set 7 | praya
# Processing Record 50 of Set 7 | porto novo
# Processing Record 1 of Set 8 | erdenet
# Processing Record 2 of Set 8 | veraval
# Processing Record 3 of Set 8 | hofn
# Processing Record 4 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 5 of Set 8 | slave lake
# Processing Record 6 of Set 8 | nikolayevskaya
# Processing Record 7 of Set 8 | te anau
# Processing Record 8 of Set 8 | copiapo
# Processing Record 9 of Set 8 | tianpeng
# Processing Record 10 of Set 8 | yangambi
# Processing Record 11 of Set 8 | batemans bay
# Processing Record 12 of Set 8 | oranjemund
# Processing Record 13 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 8 | san patricio
# Processing Record 15 of Set 8 | bonavista
# Processing Record 16 of Set 8 | bacolod
# Processing Record 17 of Set 8 | kungurtug
# Processing Record 18 of Set 8 | cherskiy
# Processing Record 19 of Set 8 | kuznetsk
# Processing Record 20 of Set 8 | stromness
# Processing Record 21 of Set 8 | ust-kuyga
# Processing Record 22 of Set 8 | vuktyl
# Processing Record 23 of Set 8 | mucurapo
# Processing Record 24 of Set 8 | acapulco
# Processing Record 25 of Set 8 | viljoenskroon
# Processing Record 26 of Set 8 | chapada dos guimaraes
# Processing Record 27 of Set 8 | sorong
# Processing Record 28 of Set 8 | lata
# Processing Record 29 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 8 | porto velho
# Processing Record 31 of Set 8 | ekibastuz
# Processing Record 32 of Set 8 | paamiut
# Processing Record 33 of Set 8 | oksfjord
# Processing Record 34 of Set 8 | rapid valley
# Processing Record 35 of Set 8 | cidreira
# Processing Record 36 of Set 8 | san jeronimo
# Processing Record 37 of Set 8 | tenango
# Processing Record 38 of Set 8 | holme
# Processing Record 39 of Set 8 | rosario
# Processing Record 40 of Set 8 | vilhena
# Processing Record 41 of Set 8 | cam ranh
# Processing Record 42 of Set 8 | catamarca
# Processing Record 43 of Set 8 | les cayes
# Processing Record 44 of Set 8 | marsh harbour
# Processing Record 45 of Set 8 | kalmunai
# Processing Record 46 of Set 8 | zaysan
# Processing Record 47 of Set 8 | abnub
# Processing Record 48 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 8 | lahij
# Processing Record 50 of Set 8 | sangar
# Processing Record 1 of Set 9 | kutum
# Processing Record 2 of Set 9 | dergaon
# Processing Record 3 of Set 9 | yaan
# Processing Record 4 of Set 9 | jackson
# Processing Record 5 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 9 | rio grande
# Processing Record 7 of Set 9 | traverse city
# Processing Record 8 of Set 9 | campohermoso
# Processing Record 9 of Set 9 | sosnovo-ozerskoye
# Processing Record 10 of Set 9 | la mata
# Processing Record 11 of Set 9 | narrabri
# Processing Record 12 of Set 9 | sao jose da coroa grande
# Processing Record 13 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 9 | alyangula
# Processing Record 15 of Set 9 | buraydah
# Processing Record 16 of Set 9 | nuevo ideal
# Processing Record 17 of Set 9 | umm lajj
# Processing Record 18 of Set 9 | ixtapa
# Processing Record 19 of Set 9 | matay
# Processing Record 20 of Set 9 | verkh-chebula
# Processing Record 21 of Set 9 | nordfjordeid
# Processing Record 22 of Set 9 | turukhansk
# Processing Record 23 of Set 9 | zhaotong
# Processing Record 24 of Set 9 | luganville
# Processing Record 25 of Set 9 | methoni
# Processing Record 26 of Set 9 | lagoa
# Processing Record 27 of Set 9 | kirkuk
# Processing Record 28 of Set 9 | bay roberts
# Processing Record 29 of Set 9 | mondolfo
# Processing Record 30 of Set 9 | manokwari
# Processing Record 31 of Set 9 | pop
# Processing Record 32 of Set 9 | winnemucca
# Processing Record 33 of Set 9 | matiri
# Processing Record 34 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 9 | phulabani
# Processing Record 36 of Set 9 | gasa
# Processing Record 37 of Set 9 | hithadhoo
# Processing Record 38 of Set 9 | bryan
# Processing Record 39 of Set 9 | talaya
# Processing Record 40 of Set 9 | bengkulu
# Processing Record 41 of Set 9 | sioux lookout
# Processing Record 42 of Set 9 | nuevo progreso
# Processing Record 43 of Set 9 | yerbogachen
# Processing Record 44 of Set 9 | port blair
# Processing Record 45 of Set 9 | puerto narino
# Processing Record 46 of Set 9 | samarai
# Processing Record 47 of Set 9 | la ronge
# Processing Record 48 of Set 9 | suzun
# Processing Record 49 of Set 9 | tarancon
# Processing Record 50 of Set 9 | megion
# Processing Record 1 of Set 10 | sarkand
# Processing Record 2 of Set 10 | panaba
# Processing Record 3 of Set 10 | santa cruz
# Processing Record 4 of Set 10 | ambilobe
# Processing Record 5 of Set 10 | benemerito de las americas
# Processing Record 6 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 10 | pitimbu
# Processing Record 9 of Set 10 | luba
# Processing Record 10 of Set 10 | nuristan
# Processing Record 11 of Set 10 | wadi musa
# Processing Record 12 of Set 10 | ca mau
# Processing Record 13 of Set 10 | moctezuma
# Processing Record 14 of Set 10 | nuuk
# Processing Record 15 of Set 10 | los llanos de aridane
# Processing Record 16 of Set 10 | rovaniemi
# Processing Record 17 of Set 10 | chandbali
# Processing Record 18 of Set 10 | ola
# Processing Record 19 of Set 10 | abbeville
# Processing Record 20 of Set 10 | marzuq
# Processing Record 21 of Set 10 | las cruces
# Processing Record 22 of Set 10 | saint-augustin
# Processing Record 23 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 25 of Set 10 | hambantota
# Processing Record 26 of Set 10 | atherton
# Processing Record 27 of Set 10 | karmaskaly
# Processing Record 28 of Set 10 | goure
# Processing Record 29 of Set 10 | rosa zarate
# Processing Record 30 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 10 | piranhas
# Processing Record 32 of Set 10 | hermiston
# Processing Record 33 of Set 10 | santa rosa
# Processing Record 34 of Set 10 | karlstad
# Processing Record 35 of Set 10 | labytnangi
# Processing Record 36 of Set 10 | salalah
# Processing Record 37 of Set 10 | bogovarovo
# Processing Record 38 of Set 10 | olinda
# Processing Record 39 of Set 10 | solnechnyy
# Processing Record 40 of Set 10 | mino
# Processing Record 41 of Set 10 | ugoofaaru
# Processing Record 42 of Set 10 | pisco
# Processing Record 43 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 10 | marquette
# Processing Record 45 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 10 | fare
# Processing Record 47 of Set 10 | dauriya
# Processing Record 48 of Set 10 | ambovombe
# Processing Record 49 of Set 10 | klaksvik
# Processing Record 50 of Set 10 | ferrol
# Processing Record 1 of Set 11 | weligama
# Processing Record 2 of Set 11 | kaputa
# Processing Record 3 of Set 11 | margate
# Processing Record 4 of Set 11 | shelburne
# Processing Record 5 of Set 11 | esperance
# Processing Record 6 of Set 11 | dingle
# Processing Record 7 of Set 11 | goderich
# Processing Record 8 of Set 11 | omsukchan
# Processing Record 9 of Set 11 | kaset sombun
# Processing Record 10 of Set 11 | byron bay
# Processing Record 11 of Set 11 | bitung
# Processing Record 12 of Set 11 | cartagena
# Processing Record 13 of Set 11 | komsomolskoye
# Processing Record 14 of Set 11 | tabou
# Processing Record 15 of Set 11 | skaerbaek
# Processing Record 16 of Set 11 | sisimiut
# Processing Record 17 of Set 11 | tabas
# Processing Record 18 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 11 | mandera
# Processing Record 20 of Set 11 | valdivia
# Processing Record 21 of Set 11 | bonthe
# Processing Record 22 of Set 11 | xuddur
# Processing Record 23 of Set 11 | horn
# Processing Record 24 of Set 11 | touros
# Processing Record 25 of Set 11 | danane
# Processing Record 26 of Set 11 | udachnyy
# Processing Record 27 of Set 11 | ballina
# Processing Record 28 of Set 11 | marion
# Processing Record 29 of Set 11 | bandundu
# Processing Record 30 of Set 11 | karema
# Processing Record 31 of Set 11 | pinega
# Processing Record 32 of Set 11 | gravdal
# Processing Record 33 of Set 11 | tiarei
# Processing Record 34 of Set 11 | mikhaylovka
# Processing Record 35 of Set 11 | eyl
# Processing Record 36 of Set 11 | kiama
# Processing Record 37 of Set 11 | kalianget
# Processing Record 38 of Set 11 | puerto escondido
# Processing Record 39 of Set 11 | wamba
# Processing Record 40 of Set 11 | hidalgo
# Processing Record 41 of Set 11 | canon city
# Processing Record 42 of Set 11 | novi bilokorovychi
# Processing Record 43 of Set 11 | mayna
# Processing Record 44 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 11 | urengoy
# Processing Record 46 of Set 11 | kasongo
# Processing Record 47 of Set 11 | burgeo
# Processing Record 48 of Set 11 | aktash
# Processing Record 49 of Set 11 | zambezi
# Processing Record 50 of Set 11 | linxia
# Processing Record 1 of Set 12 | urumqi
# Processing Record 2 of Set 12 | valcele
# Processing Record 3 of Set 12 | havre-saint-pierre
# Processing Record 4 of Set 12 | nantucket
# Processing Record 5 of Set 12 | pangnirtung
# Processing Record 6 of Set 12 | bilibino
# Processing Record 7 of Set 12 | kargasok
# Processing Record 8 of Set 12 | nedjo
# Processing Record 9 of Set 12 | poum
# Processing Record 10 of Set 12 | chalmette
# Processing Record 11 of Set 12 | swellendam
# Processing Record 12 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 12 | sechura
# Processing Record 14 of Set 12 | san andres
# Processing Record 15 of Set 12 | makhinjauri
# Processing Record 16 of Set 12 | inuvik
# Processing Record 17 of Set 12 | flinders
# Processing Record 18 of Set 12 | sheridan
# Processing Record 19 of Set 12 | pervomayskoye
# Processing Record 20 of Set 12 | sydney mines
# Processing Record 21 of Set 12 | tazovskiy
# Processing Record 22 of Set 12 | malaya vishera
# Processing Record 23 of Set 12 | yamethin
# Processing Record 24 of Set 12 | mecca
# Processing Record 25 of Set 12 | puerto plata
# Processing Record 26 of Set 12 | champerico
# Processing Record 27 of Set 12 | atasu
# Processing Record 28 of Set 12 | craidorolt
# Processing Record 29 of Set 12 | bolobo
# Processing Record 30 of Set 12 | aiken
# Processing Record 31 of Set 12 | nortelandia
# Processing Record 32 of Set 12 | taoudenni
# Processing Record 33 of Set 12 | rorvik
# Processing Record 34 of Set 12 | maumere
# Processing Record 35 of Set 12 | kincardine
# Processing Record 36 of Set 12 | general roca
# Processing Record 37 of Set 12 | san ramon
# Processing Record 38 of Set 12 | drayton valley
# Processing Record 39 of Set 12 | dubinino
# Processing Record 40 of Set 12 | beyneu
# Processing Record 41 of Set 12 | mahanoro
# Processing Record 42 of Set 12 | qena
# Processing Record 43 of Set 12 | contai
# Processing Record 44 of Set 12 | bijie
# Processing Record 45 of Set 12 | kyrksaeterora
# Processing Record 46 of Set 12 | ha tinh
# Processing Record 47 of Set 12 | binzhou
# Processing Record 48 of Set 12 | oktyabrskoye
# Processing Record 49 of Set 12 | qasigiannguit
# Processing Record 50 of Set 12 | khromtau
# Processing Record 1 of Set 13 | manacapuru
# Processing Record 2 of Set 13 | springbok
# Processing Record 3 of Set 13 | imbituba
# Processing Record 4 of Set 13 | hovd
# Processing Record 5 of Set 13 | qeshm
# Processing Record 6 of Set 13 | maldonado
# Processing Record 7 of Set 13 | moron
# Processing Record 8 of Set 13 | shingu
# Processing Record 9 of Set 13 | lengshuitan
# Processing Record 10 of Set 13 | waddan
# Processing Record 11 of Set 13 | pathein
# Processing Record 12 of Set 13 | likoporia
# City not found. Skipping...
# Processing Record 13 of Set 13 | isilkul
# Processing Record 14 of Set 13 | mersing
# Processing Record 15 of Set 13 | alpatovo
# Processing Record 16 of Set 13 | north port
# Processing Record 17 of Set 13 | vardo
# Processing Record 18 of Set 13 | alihe
# Processing Record 19 of Set 13 | igarka
# Processing Record 20 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 13 | krasnozerskoye
# Processing Record 22 of Set 13 | suhbaatar
# Processing Record 23 of Set 13 | asilah
# Processing Record 24 of Set 13 | chengde
# Processing Record 25 of Set 13 | vestmanna
# Processing Record 26 of Set 13 | jacareacanga
# Processing Record 27 of Set 13 | halifax
# Processing Record 28 of Set 13 | bocana de paiwas
# Processing Record 29 of Set 13 | ternate
# Processing Record 30 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 13 | hornepayne
# Processing Record 32 of Set 13 | karaton
# Processing Record 33 of Set 13 | sola
# Processing Record 34 of Set 13 | kathmandu
# Processing Record 35 of Set 13 | havoysund
# Processing Record 36 of Set 13 | bremerton
# Processing Record 37 of Set 13 | bereda
# Processing Record 38 of Set 13 | burtunay
# Processing Record 39 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 13 | quimper
# Processing Record 41 of Set 13 | boende
# Processing Record 42 of Set 13 | lubao
# Processing Record 43 of Set 13 | windsor
# Processing Record 44 of Set 13 | bambanglipuro
# Processing Record 45 of Set 13 | carbonia
# Processing Record 46 of Set 13 | yumen
# Processing Record 47 of Set 13 | kerman
# Processing Record 48 of Set 13 | newtonmore
# Processing Record 49 of Set 13 | avera
# Processing Record 50 of Set 13 | bedesa
# Processing Record 1 of Set 14 | north bend
# Processing Record 2 of Set 14 | saint anthony
# Processing Record 3 of Set 14 | guerrero negro
# Processing Record 4 of Set 14 | itoman
# Processing Record 5 of Set 14 | santa elena
# Processing Record 6 of Set 14 | tuatapere
# Processing Record 7 of Set 14 | mayumba
# Processing Record 8 of Set 14 | gimbi
# Processing Record 9 of Set 14 | almaznyy
# Processing Record 10 of Set 14 | nouadhibou
# Processing Record 11 of Set 14 | svetlaya
# Processing Record 12 of Set 14 | muhos
# Processing Record 13 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 14 | marawi
# Processing Record 15 of Set 14 | karlskrona
# Processing Record 16 of Set 14 | lively
# Processing Record 17 of Set 14 | saint-pierre
# Processing Record 18 of Set 14 | opuwo
# Processing Record 19 of Set 14 | gornopravdinsk
# Processing Record 20 of Set 14 | rebrikha
# Processing Record 21 of Set 14 | changli
# Processing Record 22 of Set 14 | muisne
# Processing Record 23 of Set 14 | eunice
# Processing Record 24 of Set 14 | olga
# Processing Record 25 of Set 14 | limon
# Processing Record 26 of Set 14 | takoradi
# Processing Record 27 of Set 14 | cap malheureux
# Processing Record 28 of Set 14 | aykhal
# Processing Record 29 of Set 14 | fairview
# Processing Record 30 of Set 14 | mogadishu
# Processing Record 31 of Set 14 | ponta delgada
# Processing Record 32 of Set 14 | ratnagiri
# Processing Record 33 of Set 14 | ati
# Processing Record 34 of Set 14 | qabis
# City not found. Skipping...
# Processing Record 35 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 36 of Set 14 | mnogovershinnyy
# Processing Record 37 of Set 14 | usolye-sibirskoye
# Processing Record 38 of Set 14 | dombas
# Processing Record 39 of Set 14 | bojnurd
# Processing Record 40 of Set 14 | korla
# Processing Record 41 of Set 14 | vestmannaeyjar
# Processing Record 42 of Set 14 | imeni poliny osipenko
# Processing Record 43 of Set 14 | biak
# Processing Record 44 of Set 14 | cururupu
# Processing Record 45 of Set 14 | kerouane
# Processing Record 46 of Set 14 | abu samrah
# Processing Record 47 of Set 14 | mineral wells
# Processing Record 48 of Set 14 | mazagao
# Processing Record 49 of Set 14 | belmonte
# Processing Record 50 of Set 14 | buala
# Processing Record 1 of Set 15 | mogok
# Processing Record 2 of Set 15 | tortoli
# Processing Record 3 of Set 15 | laguna
# Processing Record 4 of Set 15 | houma
# Processing Record 5 of Set 15 | manali
# Processing Record 6 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 15 | kenai
# Processing Record 8 of Set 15 | maraa
# Processing Record 9 of Set 15 | lakshettipet
# Processing Record 10 of Set 15 | guane
# Processing Record 11 of Set 15 | dera ghazi khan
# Processing Record 12 of Set 15 | tateyama
# Processing Record 13 of Set 15 | ban nahin
# Processing Record 14 of Set 15 | athabasca
# Processing Record 15 of Set 15 | pamanukan
# Processing Record 16 of Set 15 | epping
# Processing Record 17 of Set 15 | smithers
# Processing Record 18 of Set 15 | odlabari
# Processing Record 19 of Set 15 | arsenyev
# Processing Record 20 of Set 15 | zouxian
# City not found. Skipping...
# Processing Record 21 of Set 15 | tautira
# Processing Record 22 of Set 15 | simeykyne
# Processing Record 23 of Set 15 | adamovka
# Processing Record 24 of Set 15 | westerstede
# Processing Record 25 of Set 15 | mocuba
# Processing Record 26 of Set 15 | znamenskoye
# Processing Record 27 of Set 15 | kieta
# Processing Record 28 of Set 15 | hay river
# Processing Record 29 of Set 15 | skjervoy
# Processing Record 30 of Set 15 | chara
# Processing Record 31 of Set 15 | isoka
# Processing Record 32 of Set 15 | jeremie
# Processing Record 33 of Set 15 | koumac
# Processing Record 34 of Set 15 | coahuayana
# Processing Record 35 of Set 15 | humberto de campos
# Processing Record 36 of Set 15 | coihaique
# Processing Record 37 of Set 15 | severka
# Processing Record 38 of Set 15 | mendoza
# Processing Record 39 of Set 15 | high rock
# Processing Record 40 of Set 15 | tommot
# Processing Record 41 of Set 15 | curtea de arges
# Processing Record 42 of Set 15 | uruzgan
# Processing Record 43 of Set 15 | hami
# Processing Record 44 of Set 15 | komsomolskiy
# Processing Record 45 of Set 15 | maragogi
# Processing Record 46 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 47 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 15 | ubatuba
# Processing Record 50 of Set 15 | nago
# Processing Record 1 of Set 16 | san francisco
# Processing Record 2 of Set 16 | namatanai
# Processing Record 3 of Set 16 | raudeberg
# Processing Record 4 of Set 16 | usinsk
# Processing Record 5 of Set 16 | kijang
# Processing Record 6 of Set 16 | andenes
# Processing Record 7 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 16 | siocon
# Processing Record 9 of Set 16 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 16 | rio gallegos
# Processing Record 11 of Set 16 | hualmay
# Processing Record 12 of Set 16 | sorland
# Processing Record 13 of Set 16 | shemonaikha
# Processing Record 14 of Set 16 | lar gerd
# City not found. Skipping...
# Processing Record 15 of Set 16 | roma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Normal      US  40.5142  -88.9906     70.11        45           0
# 1           Castro      BR -24.7911  -50.0119     76.82        39          60
# 2  Haines Junction      CA  60.7522 -137.5108     19.63        96         100
# 3        Busselton      AU -33.6500  115.3333     53.58        82          70
# 4       Australind      AU -33.2667  115.7167     53.58        82          44
# 5          Fortuna      US  40.5982 -124.1573     39.92        98         100
# 6           Atuona      PF  -9.8000 -139.0333     77.14        80          10
# 7   Saint-Philippe      RE -21.3585   55.7679     74.79        74          99
# 8          Rikitea      PF -23.1203 -134.9692     71.69        88          97
# 9          Xuanhua      CN  40.6103  115.0447     46.44        74          26
#
#    Wind Speed Current Description
# 0       25.32           clear sky
# 1        7.67       broken clouds
# 2        2.62     overcast clouds
# 3       15.82       broken clouds
# 4       11.59    scattered clouds
# 5        9.22     overcast clouds
# 6       14.27           clear sky
# 7        6.69     overcast clouds
# 8       11.70          light rain
# 9        5.03    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
